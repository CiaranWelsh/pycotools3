# %% [markdown]
# # Get model file

# %%
# %matplotlib inline
import os,glob

for i in glob.glob('*.cps'):
    kholodenko_model= os.path.abspath(i)
    
print kholodenko_model
print os.path.isfile(kholodenko_model)
# Out:
# /home/b3053674/Documents/PyCoTools/PyCoTools/PyCoToolsTutorial/Kholodenko.cps
# True

# %% [markdown]
# # Deterministic Time Course
# ## Save data to file

# %%
import PyCoTools
PyCoTools.pycopi.TimeCourse(kholodenko_model,
                           Start = 0, End= 1000, Intervals = 1000, StepSize = 1,
                           ReportName ='kholodenko_time_course.txt')
# Out:
# DEBUG:PyCoTools.pycopi:pycopi:131:copasi file Kholodenko.cps has been parsed into Python
# DEBUG:PyCoTools.pycopi:pycopi:131:copasi file Kholodenko.cps has been parsed into Python
# DEBUG:PyCoTools.pycopi:pycopi:131:copasi file Kholodenko.cps has been parsed into Python
# DEBUG:PyCoTools.pycopi:pycopi:131:copasi file Kholodenko.cps has been parsed into Python
# DEBUG:PyCoTools.pycopi:pycopi:998:created a 'time_course' type report
# DEBUG:PyCoTools.pycopi:pycopi:142:File Kholodenko.cps written to
# /home/b3053674/Documents/PyCoTools/PyCoTools/PyCoToolsTutorial/Kholodenko.cps
# DEBUG:PyCoTools.pycopi:pycopi:131:copasi file Kholodenko.cps has been parsed into Python
# DEBUG:PyCoTools.pycopi:pycopi:131:copasi file Kholodenko.cps has been parsed into Python
# DEBUG:PyCoTools.pycopi:pycopi:998:created a 'time_course' type report
# DEBUG:PyCoTools.pycopi:pycopi:142:File Kholodenko.cps written to
# /home/b3053674/Documents/PyCoTools/PyCoTools/PyCoToolsTutorial/Kholodenko.cps
# ...

# %% [markdown]
# ## Plot time course results

# %%
import PyCoTools
PyCoTools.pycopi.TimeCourse(kholodenko_model,
                           Start = 0, End= 1000, Intervals = 1000, StepSize = 1,
                           ReportName ='kholodenko_time_course.txt',
                           Plot = 'true')
# Out:
# DEBUG:PyCoTools.pycopi:pycopi:131:copasi file Kholodenko.cps has been parsed into Python
# DEBUG:PyCoTools.pycopi:pycopi:131:copasi file Kholodenko.cps has been parsed into Python
# DEBUG:PyCoTools.pycopi:pycopi:131:copasi file Kholodenko.cps has been parsed into Python
# DEBUG:PyCoTools.pycopi:pycopi:131:copasi file Kholodenko.cps has been parsed into Python
# DEBUG:PyCoTools.pycopi:pycopi:998:created a 'time_course' type report
# DEBUG:PyCoTools.pycopi:pycopi:142:File Kholodenko.cps written to
# /home/b3053674/Documents/PyCoTools/PyCoTools/PyCoToolsTutorial/Kholodenko.cps
# DEBUG:PyCoTools.pycopi:pycopi:131:copasi file Kholodenko.cps has been parsed into Python
# DEBUG:PyCoTools.pycopi:pycopi:131:copasi file Kholodenko.cps has been parsed into Python
# DEBUG:PyCoTools.pycopi:pycopi:998:created a 'time_course' type report
# DEBUG:PyCoTools.pycopi:pycopi:142:File Kholodenko.cps written to
# /home/b3053674/Documents/PyCoTools/PyCoTools/PyCoToolsTutorial/Kholodenko.cps
# ...

# %% [markdown]
# ## Select specific model species to capture as output

# %%
import PyCoTools
PyCoTools.pycopi.TimeCourse(kholodenko_model,
                           Start = 0, End= 1000, Intervals = 1000, StepSize = 1,
                           ReportName ='kholodenko_time_course.txt',
                           Plot = 'true',
                           Metabolites = ['Mek1','Mos-P'],
                           GlobalQuantities = [])

# %% [markdown]
# # Parameter Estimation
# ## Run a single parameter estimation

# %%
import PyCoTools
## simulate some data to use in parameter estimation
TC = PyCoTools.pycopi.TimeCourse(kholodenko_model,
                           Start = 0, End= 1000, Intervals = 1000, StepSize = 1,
                           ReportName ='kholodenko_time_course.txt')
## Use the TimeCourse kwargs dictionary to get path to simulated experimental data 
PE=PyCoTools.pycopi.ParameterEstimation(kholodenko_model,TC.kwargs['ReportName'],
                                       Method = 'HookeJeeves',
                                       IterationLimit=100,
                                       Tolerance=1e-10,
                                       ReportName = 'parameter_estimation_results.txt',
                                       ConfigFilename = 'Fit1ConfigFile.xlsx',
                                       )

## get a config file
PE.write_item_template()

os.path.isfile(PE.kwargs['ConfigFilename'])
## Now modify the config file

PE.set_up()
PE.run()

# %% [markdown]
# ## Run single parameter estimation with visualization

# %%
import PyCoTools
## simulate some data to use in parameter estimation
TC = PyCoTools.pycopi.TimeCourse(kholodenko_model,
                           Start = 0, End= 1000, Intervals = 1000, StepSize = 1,
                           ReportName ='kholodenko_time_course.txt')
## Use the TimeCourse kwargs dictionary to get path to simulated experimental data 
PE=PyCoTools.pycopi.ParameterEstimation(kholodenko_model,TC.kwargs['ReportName'],
                                       Method = 'HookeJeeves',
                                       IterationLimit=100,
                                       Tolerance=1e-10,
                                       ReportName = 'parameter_estimation_results.txt',
                                       ConfigFilename = 'Fit1ConfigFile.xlsx',
                                       Plot='true')

## get a config file
PE.write_item_template()

os.path.isfile(PE.kwargs['ConfigFilename'])
## Now modify the config file

PE.set_up()
PE.run()
# Out:
# DEBUG:PyCoTools.pycopi:pycopi:131:copasi file Kholodenko.cps has been parsed into Python
# DEBUG:PyCoTools.pycopi:pycopi:131:copasi file Kholodenko.cps has been parsed into Python
# DEBUG:PyCoTools.pycopi:pycopi:131:copasi file Kholodenko.cps has been parsed into Python
# DEBUG:PyCoTools.pycopi:pycopi:131:copasi file Kholodenko.cps has been parsed into Python
# DEBUG:PyCoTools.pycopi:pycopi:998:created a 'time_course' type report
# DEBUG:PyCoTools.pycopi:pycopi:142:File Kholodenko.cps written to
# /home/b3053674/Documents/PyCoTools/PyCoTools/PyCoToolsTutorial/Kholodenko.cps
# DEBUG:PyCoTools.pycopi:pycopi:131:copasi file Kholodenko.cps has been parsed into Python
# DEBUG:PyCoTools.pycopi:pycopi:131:copasi file Kholodenko.cps has been parsed into Python
# DEBUG:PyCoTools.pycopi:pycopi:998:created a 'time_course' type report
# DEBUG:PyCoTools.pycopi:pycopi:142:File Kholodenko.cps written to
# /home/b3053674/Documents/PyCoTools/PyCoTools/PyCoToolsTutorial/Kholodenko.cps
# ...

# %%
    3. Plot and save results in the same directory as the model file
