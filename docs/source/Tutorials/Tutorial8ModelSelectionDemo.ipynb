# %% [markdown]
# ## Model Selection Workflow

# %% [markdown]
# In this tutorial we create three model alternatives using a PyCoTools wrapper around tellurium and antimony. Data is simualted from the negative feedback model and used in a model selection problem to distinguish between three model candidates. To perform model selection using PyCoTools, all models and data files should be placed into a new directory. Data files should conform to the same format that the COPASI GUI requires with the addition that the headers must match model variables exactly (or have the suffix `_indep` for independent variables). The `tasks.MultiModelFit` class detects COPASI and data files in the folder and sets up a multi-parameter estimation for each using the `tasks.MultiParameterEstimation` class. After fitting, the `viz.ModelSelection` class is used to calculate AIC and BIC and to plot model selection criteria.

# %%
import os, glob
from pycotools import model, tasks, viz, misc
import seaborn
# %matplotlib inline
seaborn.set_context('notebook')

working_directory = r'/home/b3053674/Documents/Models/2018/'\
                     '03_March/ModelSelectionDemonstration'

## create directory for our model selection analysis
model_selection_dir = os.path.join(working_directory, 'ModelSelection')

if not os.path.isdir(model_selection_dir):
    os.makedirs(model_selection_dir)
    
## create paths to three model alternatives. 
## This should be inside a new clean directory
copasi_file1 = os.path.join(model_selection_dir, 'negative_feedback.cps')
copasi_file2 = os.path.join(model_selection_dir, 'positive_feedback.cps')
copasi_file3 = os.path.join(model_selection_dir, 'feedforward.cps')

## build models with antimony
with model.BuildAntimony(copasi_file1) as loader:
    mod1 = loader.load(
        """
        model negative_feedback
            compartment cell = 1.0
            var A in cell
            var B in cell

            vAProd = 0.1
            kADeg = 0.2
            kBProd = 0.3
            kBDeg = 0.4
            A = 0
            B = 0

            AProd: => A; cell*vAProd
            ADeg: A =>; cell*kADeg*A*B
            BProd: => B; cell*kBProd*A
            BDeg: B => ; cell*kBDeg*B
        end
        """
    )

with model.BuildAntimony(copasi_file2) as loader:
    mod2 = loader.load(
        """
        model positive_feedback
            compartment cell = 1.0
            var A in cell
            var B in cell

            vAProd = 0.1
            kADeg = 0.2
            kBProd = 0.3
            kBDeg = 0.4
            vBasalAProd = 0.001
            A = 0
            B = 0

            AProd: => A; cell*vAProd*B+vBasalAProd
            ADeg: A =>; cell*kADeg*A
            BProd: => B; cell*kBProd*A
            BDeg: B => ; cell*kBDeg*B
        end
        """
    )

with model.BuildAntimony(copasi_file3) as loader:
    mod3 = loader.load(
        """
        model feed_forward
            compartment cell = 1.0
            var A in cell
            var B in cell
            var C in cell

            vAProd = 0.1
            kADeg = 0.2
            kBProd = 0.3
            kBDeg = 0.4
            kCDeg = 0.5
            kCProd = 0.6
            A = 0
            B = 0
            C = 0

            AProd: => A; cell*vAProd
            ADeg: A =>; cell*kADeg*A
            BProd: => B; cell*kBProd*A
            BDeg: B => ; cell*kBDeg*B
            CProd: => C; cell*kCProd*A*B
            CDeg: C => ; cell*kCDeg*C
        end
        """
    )

print(mod1)
print(mod2)
print(mod3)

# %% [markdown]
# ### Simulate the Models

# %%
for mod in [mod1, mod2, mod3]:
    TC = tasks.TimeCourse(mod, end=100, intervals=100, step_size=1)
    viz.PlotTimeCourse(TC, separate=False)

# %% [markdown]
# ### Simulate Synthetic Data

# %%
## Create time course data from negative feedback model
## This data is automatically saved as a report in the 
## same directory as the model
TC = tasks.TimeCourse(mod1, end=100, intervals=10, step_size=10)

## Make sure that the headings inside the data file are
## identical to model variables (and not encloded by '[]'. )
## overwrites data file with new data file without the extra [].
misc.format_timecourse_data(TC.report_name)
# Out:
#     Time         B         A  kBDeg  kBProd  kADeg  vAProd
# 0      0  0.000000  0.000000    0.4     0.3    0.2     0.1
# 1     10  0.464639  0.748359    0.4     0.3    0.2     0.1
# 2     20  0.613698  0.823275    0.4     0.3    0.2     0.1
# 3     30  0.613132  0.816723    0.4     0.3    0.2     0.1
# 4     40  0.612348  0.816455    0.4     0.3    0.2     0.1
# 5     50  0.612369  0.816496    0.4     0.3    0.2     0.1
# 6     60  0.612373  0.816497    0.4     0.3    0.2     0.1
# 7     70  0.612372  0.816497    0.4     0.3    0.2     0.1
# 8     80  0.612372  0.816497    0.4     0.3    0.2     0.1
# 9     90  0.612372  0.816497    0.4     0.3    0.2     0.1
# 10   100  0.612372  0.816497    0.4     0.3    0.2     0.1

# %% [markdown]
# ### Perform Model Selection
# Here we fit each model to the same data set which was simulated from the negative feedback model. We use the genetic algorithm

# %%
MMF = tasks.MultiModelFit(model_selection_dir,
                          method='genetic_algorithm',
                          population_size=30,
                          number_of_generations=60,
                          copy_number=2,
                          pe_number=20,
                          run_mode=True,
                          overwrite_config_file=True,
                          lower_bound=1e-2,
                          upper_bound=1e2)
MMF.write_config_file()
MMF.setup()
MMF.run()
# Out:
# pycotools.tasks:INFO:4302:    project dir is --> /home/b3053674/Documents/Models/2018/03_March/ModelSelectionDemonstration/ModelSelection
# pycotools.tasks:INFO:4267:    Creating workspace from project_dir
# pycotools.tasks:INFO:4285:    Workspace created
# pycotools.tasks:INFO:4248:    Running models from /home/b3053674/Documents/Models/2018/03_March/ModelSelectionDemonstration/ModelSelection/negative_feedback/MultipleParameterEstimationResults
# pycotools.tasks:INFO:3740:    running model: 0
# pycotools.tasks:INFO:3740:    running model: 1
# pycotools.tasks:INFO:4248:    Running models from /home/b3053674/Documents/Models/2018/03_March/ModelSelectionDemonstration/ModelSelection/positive_feedback/MultipleParameterEstimationResults
# pycotools.tasks:INFO:3740:    running model: 0
# pycotools.tasks:INFO:3740:    running model: 1
# pycotools.tasks:INFO:4248:    Running models from /home/b3053674/Documents/Models/2018/03_March/ModelSelectionDemonstration/ModelSelection/feedforward/MultipleParameterEstimationResults
# pycotools.tasks:INFO:3740:    running model: 0
# pycotools.tasks:INFO:3740:    running model: 1

# %% [markdown]
# ### Calculate and Plot Model Selection Criteria
# Models are compared using violin plots which can be saved to file using the `savefig=True` argument.
# In a violin plot:
# * The central spot is the median of the distribution
# * The thin line down the middle represents the 95% confidence interval
# * The thick centeral line represents the interquartile range
# * The width of the violin is a kernel density estimation representing the shape of the data

# %%
## Automatically produces Violin Plots and saves a 
## csv file containing model selection criteria
MS = viz.ModelSelection(MMF, savefig=True)
# Out:
# pycotools.viz:INFO:3623:    Violin plot saved to : "/home/b3053674/Documents/Models/2018/03_March/ModelSelectionDemonstration/ModelSelection/ModelSelectionGraphs/ViolinPlot_RSS.png"
# pycotools.viz:INFO:3623:    Violin plot saved to : "/home/b3053674/Documents/Models/2018/03_March/ModelSelectionDemonstration/ModelSelection/ModelSelectionGraphs/ViolinPlot_AICc.png"
# pycotools.viz:INFO:3623:    Violin plot saved to : "/home/b3053674/Documents/Models/2018/03_March/ModelSelectionDemonstration/ModelSelection/ModelSelectionGraphs/ViolinPlot_BIC.png"
# pycotools.viz:INFO:3458:    model selection data saved to /home/b3053674/Documents/Models/2018/03_March/ModelSelectionDemonstration/ModelSelection/ModelSelectionGraphs/ModelSelectionCriteria.csv

# %% [markdown]
# Model selection criteria is also available from the `ModelSelection.model_selection_data` attribute.

# %%
MS.model_selection_data.head()
# Out:
#          feedforwa                         negative_feedba              \
#                RSS        AICc         BIC             RSS        AICc
# RSS Rank
# 0         0.009863 -560.367290 -543.660398        0.000035 -941.415291
# 1         0.009918 -560.000346 -543.293453        0.000051 -916.067018
# 2         0.009934 -559.896087 -543.189194        0.000061 -903.795657
# 3         0.009938 -559.868720 -543.161827        0.000092 -876.664332
# 4         0.009942 -559.844882 -543.137990        0.000118 -860.659438
#
#                      positive_feedba
#                  BIC             RSS        AICc         BIC
# RSS Rank
# 0        -929.277363        0.001443 -693.205594 -678.878011
# 1        -903.929090        0.001572 -687.566491 -673.238908
# 2        -891.657729        0.001586 -686.989696 -672.662112
# 3        -864.526404        0.001630 -685.202219 -670.874636
# 4        -848.521509        0.001735 -681.055345 -666.727762

# %% [markdown]
# ### Best Parameters
# Original Parameters were:
#
#     * A = 0
#     * B = 0
#     * kADeg = 0.2
#     * kBDeg = 0.4
#     * kBProd = 0.3
#     * vAProd = 0.1
#
#
# Best estimated parameters for negative feedback model were:

# %%
## get key for negative feedback model
MMF.keys()
# Out:
# ['/home/b3053674/Documents/Models/2018/03_March/ModelSelectionDemonstration/ModelSelection/negative_feedback/negative_feedback.cps',
#  '/home/b3053674/Documents/Models/2018/03_March/ModelSelectionDemonstration/ModelSelection/positive_feedback/positive_feedback.cps',
#  '/home/b3053674/Documents/Models/2018/03_March/ModelSelectionDemonstration/ModelSelection/feedforward/feedforward.cps']

# %%
## Parse parameter estimation data into pandas.DataFrame
negetive_feedback_MPE = MMF['/home/b3053674/Documents/Models/2018/03_March/ModelSelectionDemonstration/ModelSelection/negative_feedback/negative_feedback.cps']
data = viz.Parse(negetive_feedback_MPE).data
data.iloc[0]
# Out:
# A         0.010000
# B         0.011017
# kADeg     0.200469
# kBDeg     0.396521
# kBProd    0.301833
# vAProd    0.100384
# RSS       0.000035
# Name: 0, dtype: float64

# %% [markdown]
# ### Interpretation
# As expected, the RSS, AICc and BIC all support the negative feedback model as the model which best fits the data.

# %% [markdown]
# ### Subsequent Analysis
# The `tasks.MultiModelFit` object is a container object much like a dictionary for a series of `tasks.MultiParameterEstimation` objects. You can iterate over the `tasks.MultiModelFit` object to get a handle on each of the `tasks.MultiParameterEstimation` objects. Classes in the `viz` module can then be used to inspect the estimations.
#
# #### Ensemble Time Courses

# %%
for MPE in MMF:
    viz.PlotTimeCourseEnsemble(MPE, y=[i.name for i in MPE.model.metabolites])
# Out:
# pycotools.viz:INFO:1536:    Plotting "B"
# /home/b3053674/anaconda2/envs/pycotools/lib/python2.7/site-packages/seaborn-0.8.1-py2.7.egg/seaborn/timeseries.py:184: UserWarning:
#
# The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
# pycotools.viz:INFO:1536:    Plotting "A"
# pycotools.viz:INFO:1536:    Plotting "B"
# pycotools.viz:INFO:1536:    Plotting "A"
# pycotools.viz:INFO:1536:    Plotting "C"
# pycotools.viz:INFO:1536:    Plotting "B"
# pycotools.viz:INFO:1536:    Plotting "A"

# %% [markdown]
# #### Likelihood ranks

# %%
for MPE in MMF:
    viz.LikelihoodRanks(MPE)

# %% [markdown]
# #### Boxplots

# %%
for MPE in MMF:
    viz.Boxplots(MPE, num_per_plot=10, log10=True)

# %% [markdown]
# #### Correlations
# For the sake of simplicity, we now isolate the negative feedback model to look for correlations

# %%
## get path to the negative feedback model
negative_feedback_model_path = os.path.join(
    model_selection_dir, 'negative_feedback'
)
negative_feedback_model_path = os.path.join(
    negative_feedback_model_path, 'negative_feedback.cps'
)

## get underlying MultiParameterEstimation object
MPE = MMF[negative_feedback_model_path]

## look at pearsons correlation between parameters
viz.PearsonsCorrelation(MPE)

# %% [markdown]
# #### Scatter Graphs

# %%
viz.Scatters(MPE, 
             x=['kADeg', 'kBDeg'], 
             y=['kBProd', 'kBDeg']
            )
# Out:
# pycotools.viz:INFO:2606:    Plotting "kADeg" Vs "kBProd"
# pycotools.viz:INFO:2606:    Plotting "kADeg" Vs "kBDeg"
# pycotools.viz:INFO:2606:    Plotting "kBDeg" Vs "kBProd"
# pycotools.viz:INFO:2606:    Plotting "kBDeg" Vs "kBDeg"

# %% [markdown]
# ### Profile Likelihoods
# #### Calculation
# Use the results from the chaser estimations in the profile likelihood calculations. Here we read the data into a `pandas.DataFrame` and pass the dataframe to the `tasks.ProfileLikelihood` class. Alternatively we can supply the `parameter_path` or a dictionary argument, as described in the documentation.

# %%
data = viz.Parse(MPE.results_directory, copasi_file=MPE.model.copasi_file).data
pl = tasks.ProfileLikelihood(
    MPE.model, 
    df=data,
    index=[0, 1], 
    run=True, 
    intervals=20
)
# Out:
# pycotools.tasks:INFO:4957:    running /home/b3053674/Documents/Models/2018/03_March/ModelSelectionDemonstration/ModelSelection/negative_feedback/ProfileLikelihoods/0/A.cps
# pycotools.tasks:INFO:4957:    running /home/b3053674/Documents/Models/2018/03_March/ModelSelectionDemonstration/ModelSelection/negative_feedback/ProfileLikelihoods/0/B.cps
# pycotools.tasks:INFO:4957:    running /home/b3053674/Documents/Models/2018/03_March/ModelSelectionDemonstration/ModelSelection/negative_feedback/ProfileLikelihoods/0/kBDeg.cps
# pycotools.tasks:INFO:4957:    running /home/b3053674/Documents/Models/2018/03_March/ModelSelectionDemonstration/ModelSelection/negative_feedback/ProfileLikelihoods/0/kBProd.cps
# pycotools.tasks:INFO:4957:    running /home/b3053674/Documents/Models/2018/03_March/ModelSelectionDemonstration/ModelSelection/negative_feedback/ProfileLikelihoods/0/vAProd.cps
# pycotools.tasks:INFO:4957:    running /home/b3053674/Documents/Models/2018/03_March/ModelSelectionDemonstration/ModelSelection/negative_feedback/ProfileLikelihoods/0/kADeg.cps
# pycotools.tasks:INFO:4957:    running /home/b3053674/Documents/Models/2018/03_March/ModelSelectionDemonstration/ModelSelection/negative_feedback/ProfileLikelihoods/1/A.cps
# pycotools.tasks:INFO:4957:    running /home/b3053674/Documents/Models/2018/03_March/ModelSelectionDemonstration/ModelSelection/negative_feedback/ProfileLikelihoods/1/B.cps
# pycotools.tasks:INFO:4957:    running /home/b3053674/Documents/Models/2018/03_March/ModelSelectionDemonstration/ModelSelection/negative_feedback/ProfileLikelihoods/1/kBDeg.cps
# pycotools.tasks:INFO:4957:    running /home/b3053674/Documents/Models/2018/03_March/ModelSelectionDemonstration/ModelSelection/negative_feedback/ProfileLikelihoods/1/kBProd.cps
# pycotools.tasks:INFO:4957:    running /home/b3053674/Documents/Models/2018/03_March/ModelSelectionDemonstration/ModelSelection/negative_feedback/ProfileLikelihoods/1/vAProd.cps
# pycotools.tasks:INFO:4957:    running /home/b3053674/Documents/Models/2018/03_March/ModelSelectionDemonstration/ModelSelection/negative_feedback/ProfileLikelihoods/1/kADeg.cps

# %% [markdown]
# ### Visualization

# %%
viz.PlotProfileLikelihood(pl, title='', interpolation='cubic')

# %%
viz.PlotProfileLikelihood(pl, 
                          x=['kADeg', 'kBDeg', 'A', 'B'], 
                          y=['kBProd', 'A', 'B'], 
                          interpolation='cubic',
                          title='')
